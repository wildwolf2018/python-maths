# %% [markdown]
# # Chapter 4
# ## Symbolic Math With Python
# ### *Exercise 1 - Finding factors*

# %%
# %run factor_finder.py
# Out:
# Enter an expression: x**2 -9 * x
# x⋅(x - 9)

# %%
# %run factor_finder.py
# Out:
# Enter an expression: x**2 - 9
# (x - 3)⋅(x + 3)

# %%
# %run factor_finder.py
# Out:
# Enter an expression: x**2 + 3*x + x**3 + 2x
# Invalid expression

# %% [markdown]
# ### *Exercise 2 - Graphical equation solver*

# %%
# %matplotlib inline

# %%
# %run graphical_equation_solver.py
# Out:
# Enter first expression in terms of x and y: x+1-y
# Enter second expression in terms of x and y: -x-y
# Point of intersection
# X = -1/2, Y = 1/2

# %%
# %run graphical_equation_solver.py
# Out:
# Enter first expression in terms of x and y: x+1-y
# Enter second expression in terms of x and y: x-y
# Point of intersection does not exist.Therefore there's no solution.

# %% [markdown]
# ### *Exercise 3 - Summing a series*

# %%
# %run sum_of_series.py
# Out:
# Enter the nth term of the series: x**n/n
# Enter the number of terms: 5
# Sum of 5 terms of the series:
#  5    4    3    2
# x    x    x    x
# ── + ── + ── + ── + x
# 5    4    3    2

# %%
# %run sum_of_series.py
# Out:
# Enter the nth term of the series: a+(n-1)*d
# Enter the number of terms: 3
# Sum of 3 terms of the series:
# 3⋅a + 3⋅d

# %%
# %run sum_of_series.py
# Out:
# Enter the nth term of the series: (-1)**(n-1) * x**(2*n-1)/(2*n-1)!
# Enter the number of terms: 4
# Sum of 4 terms of the series:
#     7      5    3
#    x      x    x
# - ──── + ─── - ── + x
#   5040   120   6

# %%
# %run sum_of_series.py
# Out:
# Enter the nth term of the series: x**(n-1)/(n-1)!
# Enter the number of terms: 3
# Sum of 3 terms of the series:
#  2
# x
# ── + x + 1
# 2

# %%
# %run sum_of_series.py
# Out:
# Enter the nth term of the series: (-1)**(n-1) * x**(2*n-2)/(2*n-2)!
# Enter the number of terms: 4
# Sum of 4 terms of the series:
#     6    4    2
#    x    x    x
# - ─── + ── - ── + 1
#   720   24   2

# %% [markdown]
# ### *Exercise 4 - Solving single-variable inequalities*
