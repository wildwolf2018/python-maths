# %% [markdown]
# # Chapter 7
#
# ## Solving Calculus Problems

# %% [markdown]
# ###  #1: Verify the Continuity of a Function at a Point

# %%
# %run continuity.py
# Out:
# Enter a function of one variable: 1/x
# Enter the variable: x
# Enter the point to check the continuity at: 1
# 1/x is continuous at 1.0

# %%
# %run continuity.py
# Out:
# Enter a function of one variable: 1/x
# Enter the variable: x
# Enter the point to check the continuity at: 0
# 1/x is not continuous at 0.0

# %%
# %run continuity.py
# Out:
# Enter a function of one variable: sin(x)/x
# Enter the variable: x
# Enter the point to check the continuity at: 1
# sin(x)/x is continuous at 1.0

# %%
# %run continuity.py
# Out:
# Enter a function of one variable: sin(x)/x
# Enter the variable: x
# Enter the point to check the continuity at: 0
# sin(x)/x is not continuous at 0.0

# %% [markdown]
# ### #2: Implement the Gradient Descent

# %%
# %matplotlib inline

# %%
# %run gradient_descent.py
# Out:
# Enter a function of one variable: x**2+2*x-4
# Enter the variable: x
# Enter the initial value: 3
# x: -0.995001283742513
# Minimum value: -4.99997501283578

# %%
# %run gradient_descent.py
# Out:
# Enter a function of one variable: x**5-30*x**3+50*x
# Enter the variable: x
# Enter the initial value: -0.5
# x: -0.757452532565767
# Minimum value: -25.0846622605419

# %% [markdown]
# ### #3: Area Between Two Curves

# %% [markdown]
# ### #4: Finding the Length of a Curve
