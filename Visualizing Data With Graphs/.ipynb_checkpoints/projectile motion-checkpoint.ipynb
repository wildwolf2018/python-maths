# %%
# %matplotlib inline

# %%
# %run projectilePathPlot
# Out:
# Enter the number of trajectories: 3
# Enter the initial velocity of trajectory: 45
# Enter the angle of trajectory: 90
# Flight time for trajectory1: 9.18 seconds
# Enter the initial velocity of trajectory: 60
# Enter the angle of trajectory: 45
# Flight time for trajectory2: 8.66 seconds
# Enter the initial velocity of trajectory: 45
# Enter the angle of trajectory: 45
# Flight time for trajectory3: 6.49 seconds
