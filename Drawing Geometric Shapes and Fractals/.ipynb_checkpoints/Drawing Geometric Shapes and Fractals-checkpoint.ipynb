# %% [markdown]
# # Chapter 6
#
# ## Drawing Geometric Shapes and Fractals

# %% [markdown]
# ###  #1: Packing Circles into a Square

# %%
# %matplotlib inline

# %%
# %run packing_circles.py
# Out:
# Enter the length of a side of the square: 5
# The number of circles with radius=0.5,
# that can fitted inside a square with side length=5.0 is 16

# %% [markdown]
# ###  #2:  Drawing the Sierpin´ski Triangle

# %%
# %matplotlib inline

# %%
# %run sierpinski.py
# Out:
# Enter the number of points: 100

# %%
# %run sierpinski.py
# Out:
# Enter the number of points: 10000

# %% [markdown]
# ### #3: Exploring Hénon’s Function

# %%
# %matplotlib inline

# %%
# %run henon_func.py

# %% [markdown]
# ### #4: Drawing the Mandelbrot Set

# %%
# %matplotlib inline

# %%
# %run mandelbrot.py
